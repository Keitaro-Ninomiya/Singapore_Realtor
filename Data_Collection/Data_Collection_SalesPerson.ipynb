# %%
import requests, zipfile, io
from io import StringIO
import pandas as pd
import os
from datetime import date

url = "https://data.gov.sg/dataset/8f357dd4-96f6-4957-8a68-41b28e5e3f2f/download"
r = requests.get(url,stream=True)
z=zipfile.ZipFile(io.BytesIO(r.content))
z.extractall(r"/home/keitaro2/Singapore_Realtor/Raw_Data/Folder")

# %%
def update(date):
    dta=pd.read_csv(r"/home/keitaro2/Singapore_Realtor/Raw_Data/CEA_Salesperson_Information/dtaAgents.csv")
    dta_temp=dta.drop(columns="Last_Obs")
    dta1=pd.read_csv(r"/home/keitaro2/Singapore_Realtor/Raw_Data/Folder/cea-salesperson-information.csv")

    new=pd.concat([dta_temp,dta1]).drop_duplicates(keep=False)
    new["Last_Obs"]=date
    dta=pd.concat([dta,new])
    
    os.remove(r"/home/keitaro2/Singapore_Realtor/Raw_Data/Folder/cea-salesperson-information.csv")
    return dta

# %%
dta=update(date.today().strftime("%m/%d/%Y"))
dta.to_csv(r"/home/keitaro2/Singapore_Realtor/Raw_Data/CEA_Salesperson_Information/dtaAgents.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-60d586847f96> in <module>
# ----> 1 dta=update(date.today().strftime("%m/%d/%Y"))
#       2 dta.to_csv(r"/home/keitaro2/Singapore_Realtor/Raw_Data/CEA_Salesperson_Information/dtaAgents.csv")
#
# <ipython-input-4-9f8d7711f218> in update(date)
#       1 def update(date):
# ----> 2     dta=pd.read_csv(r"/home/keitaro2/Singapore_Realtor/Raw_Data/CEA_Salesperson_Information/dtaAgents.csv")
#       3     dta_temp=dta.drop(columns="Last_Obs")
#       4     dta1=pd.read_csv(r"/home/keitaro2/Singapore_Realtor/Raw_Data/Folder/cea-salesperson-information.csv")
#       5
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
# ...

# %%
dta=pd.read_csv(r"/home/keitaro2/Singapore_Realtor/Raw_Data/CEA_Salesperson_Information/dtaAgents.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-3b0a812e7061> in <module>
# ----> 1 dta=pd.read_csv(r"/home/keitaro2/Singapore_Realtor/Raw_Data/CEA_Salesperson_Information/dtaAgents.csv")
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
