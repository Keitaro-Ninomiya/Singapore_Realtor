# %%
from selenium import webdriver

DRIVER_PATH = "C:/Users/Keitaro Ninomiya/Programs/chromedriver_win32/chromedriver.exe"
driver = webdriver.Chrome(executable_path=DRIVER_PATH)
driver.get("https://google.com")
# Out:
# C:\Users\Keitaro Ninomiya\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   after removing the cwd from sys.path.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")

driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
driver.get("https://www.cea.gov.sg/aceas/suspended-or-revoked-salespersons-&-estate-agents/suspended-sales")
print(driver.page_source)
driver.quit()
# Out:
# C:\Users\Keitaro Ninomiya\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# ...

# %%
import unittest
import time
test_url="https://www.cea.gov.sg/aceas/suspended-or-revoked-salespersons-&-estate-agents/suspended-sales"

driver.find_element_by_xpath("//body[@class='xb-body']//div//div//div[@id='public-register']//div[@id='__qiankun_microapp_wrapper_for_xtremax_aceas_ui_internet_publicregister_1652800763696_553__' @data-name='xtremax.aceas.ui.internet.publicregister']//div//main//div[@role='main']//div[@class='wrapper']//div[@class='content-container with-custom-print custom-mobile-styling']//div//section//div[@class='custom-wrapper-btab']//div[@class='b-tabs  modified-margin has-arrow-mobile']//section[@class='b-tabs  modified-margin has-arrow-mobile']//section[@class='tab-content']//div[@class='tabl-item']//div//div[@pagination='true' @sticky='true']//div//div[@class='xb-table-wrapper custom-link']//div[@class = 'table-wrapper has-mobile-cards']//table[@class='table']//tbody//tr[@class]//")
